# %% [markdown]
# <img src="http://eikon.tpq.io/refinitiv_logo.png" width="28%" align="left" style="vertical-align: top; padding-top: 23px;">
# <img src="http://hilpisch.com/tpq_logo_long.png" width="36%" align="right" style="vertical-align: top;">

# %% [markdown]
# # Eikon Data API

# %% [markdown]
# **Vectorized Backtesting of Trading Strategies**
#
# Dr. Yves J. Hilpisch | The Python Quants GmbH
#
# <a href="http://tpq.io" target="_blank">http://tpq.io</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a> | <a href="mailto:training@tpq.io">training@tpq.io</a>
#
# <img src="http://hilpisch.com/images/tr_eikon_02.png" width=350px align=left>

# %% [markdown]
# ## The Agenda

# %% [markdown]
# This tutorial shows
#
# * how to retrieve historical end-of-day and intraday price data,
# * how to work with such data using `pandas`, `Plotly` and `Cufflinks`,
# * how to derive typical trading statistics and formulate trading strategies and
# * how to backtest such trading strategies in vectorized fashion.

# %% [markdown]
# ## Simple Moving Averages

# %% [markdown]
# Trading based on **simple moving averages (SMAs)** is a decades old strategy that has its origins in the technical stock analysis world. Brock et al. (1992), for example, empirically investigate such strategies systematically. They write:
#
# > "The term 'technical analysis' is a general heading for a myriad of trading techniques. ... In this paper, we explore two of the simplest and most popular technical rules: moving average-oscillator and trading-range break (resistance and support levels). In the first method, buy and sell signals are generated by two moving averages, a long period, and a short period. ... Our study reveals that technical analysis helps to predict stock changes."
#
# See Brock, William, Josef Lakonishok, Blake LeBaron (1992): "Simple Technical Trading Rules and the Stochastic Properties of Stock Returns." _Journal of Finance_, Vol. 47, No. 5, 1731-1764.

# %% [markdown]
# In what follows, a **trading strategy based on two SMAs, a shorter and a longer one, is analyzed** &mdash; first based on end-of-day data then based on intraday data.

# %% [markdown]
# ## Importing Required Packages

# %%
import eikon as ek  # the Eikon Python wrapper package
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks
import configparser as cp
cf.set_config_file(offline=True)  # set the plotting mode to offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# The following **Python and package versions** are used.

# %%
import sys
print(sys.version)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]

# %%
ek.__version__
# Out:
# '1.1.16'

# %%
np.__version__
# Out:
# '1.21.5'

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
cf.__version__
# Out:
# '0.17.3'

# %% [markdown]
# ## Connecting to Eikon Data API

# %% [markdown]
# This code sets the `app_id` to connect to the **Eikon Data API Proxy** which needs to be running locally.

# %%
cfg = cp.ConfigParser()
cfg.read('eikon.cfg')
# Out:
# []

# %%
#ek.set_app_key(cfg['eikon']['app_id']) #set_app_id function being deprecated
ek.set_app_key('92bffb6063bf4087a7c422252d16476aa5fe962a')

# %% [markdown]
# ## Retrieving End-of-Day Data

# %% [markdown]
# First, **end-of-day (EOD) data** for a stock is retrieved.

# %%
ric = 'AAPL.O'

# %%
data = ek.get_timeseries(ric,  # the RIC
                         fields='CLOSE',  # the required fields
                         start_date='2010-01-01',  # start date
                         end_date='2018-04-30')  # end date

# %%
data.head()  # first five rows
# Out:
# AAPL.O         CLOSE
# Date
010-08-19","2010-08-20","2010-08-23","2010-08-24","2010-08-25","2010-08-26","2010-08-27","2010-08-30","2010-08-31","2010-09-01","2010-09-02","2010-09-03","2010-09-07","2010-09-08","2010-09-09","2010-09-10","2010-09-13","2010-09-14","2010-09-15","2010-09-16","2010-09-17","2010-09-20","2010-09-21","2010-09-22","2010-09-23","2010-09-24","2010-09-27","2010-09-28","2010-09-29","2010-09-30","2010-10-01","2010-10-04","2010-10-05","2010-10-06","2010-10-07","2010-10-08","2010-10-11","2010-10-12","2010-10-13","2010-10-14","2010-10-15","2010-10-18","2010-10-19","2010-10-20","2010-10-21","2010-10-22","2010-10-25","2010-10-26","2010-10-27","2010-10-28","2010-10-29","2010-11-01","2010-11-02","2010-11-03","2010-11-04","2010-11-05","2010-11-08","2010-11-09","2010-11-10","2010-11-11","2010-11-12","2010-11-15","2010-11-16","2010-11-17","2010-11-18","2010-11-19","2010-11-22","2010-11-23","2010-11-24","2010-11-26","2010-11-29","2010-11-30","2010-12-01","2010-12-02","2010-12-03","2010-12-06","2010-12-07","2010-12-08","2010-12-09","2010-12-10","2010-12-13","2010-12-14","2010-12-15","2010-12-16","2010-12-17","2010-12-20","2010-12-21","2010-12-22","2010-12-23","2010-12-27","2010-12-28","2010-12-29","2010-12-30","2010-12-31","2011-01-03","2011-01-04","2011-01-05","2011-01-06","2011-01-07","2011-01-10","2011-01-11","2011-01-12","2011-01-13","2011-01-14","2011-01-18","2011-01-19","2011-01-20","2011-01-21","2011-01-24","2011-01-25","2011-01-26","2011-01-27","2011-01-28","2011-01-31","2011-02-01","2011-02-02","2011-02-03" ...

# %% [markdown]
# ## Deriving the SMA Values

# %% [markdown]
# `pandas` provides convenience methods to calculate **rolling statistics**, such as SMAs, in a standardized way.

# %%
SMA1 = 42  # shorter SMA window
SMA2 = 252  # longer SMA window

# %%
data['SMA1'] = data['CLOSE'].rolling(SMA1).mean()
data['SMA2'] = data['CLOSE'].rolling(SMA2).mean()

# %%
data.head()
# Out:
# AAPL.O         CLOSE  SMA1  SMA2
# Date
# 2010-01-04  7.643207   NaN   NaN
# 2010-01-05  7.656421   NaN   NaN
# 2010-01-06  7.534635   NaN   NaN
# 2010-01-07  7.520707   NaN   NaN
# 2010-01-08  7.570707   NaN   NaN

# %%
data.tail()
# Out:
# AAPL.O        CLOSE       SMA1       SMA2
# Date
# 2018-04-24   40.735  43.371845  40.573095
# 2018-04-25  40.9125  43.301310  40.592063
# 2018-04-26   41.055  43.213512  40.612440
# 2018-04-27    40.58  43.117857  40.630823
# 2018-04-30   41.315  43.041310  40.652262

# %%
data.iplot()
# Out:
# <div>                            <div id="dfa2983d-8aa2-4a9f-98f3-2862f862b209" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("dfa2983d-8aa2-4a9f-98f3-2862f862b209")) {                    Plotly.newPlot(                        "dfa2983d-8aa2-4a9f-98f3-2862f862b209",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"CLOSE","text":"","x":["2010-01-04","2010-01-05","2010-01-06","2010-01-07","2010-01-08","2010-01-11","2010-01-12","2010-01-13","2010-01-14","2010-01-15","2010-01-19","2010-01-20","2010-01-21","2010-01-22","2010-01-25","2010-01-26","2010-01-27","2010-01-28","2010-01-29","2010-02-01","2010-02-02","2010-02-03","2010-02-04","2010-02-05","2010-02-08","2010-02-09","2010-02-10","2010-02-11","2010-02-12","2010-02-16","2010-02-17","2010-02-18","2010-02-19
","2011-10-21","2011-10-24","2011-10-25","2011-10-26","2011-10-27","2011-10-28","2011-10-31","2011-11-01","2011-11-02","2011-11-03","2011-11-04","2011-11-07","2011-11-08","2011-11-09","2011-11-10","2011-11-11","2011-11-14","2011-11-15","2011-11-16","2011-11-17","2011-11-18","2011-11-21","2011-11-22","2011-11-23","2011-11-25","2011-11-28","2011-11-29","2011-11-30","2011-12-01","2011-12-02","2011-12-05","2011-12-06","2011-12-07","2011-12-08","2011-12-09","2011-12-12","2011-12-13","2011-12-14","2011-12-15","2011-12-16","2011-12-19","2011-12-20","2011-12-21","2011-12-22","2011-12-23","2011-12-27","2011-12-28","2011-12-29","2011-12-30","2012-01-03","2012-01-04","2012-01-05","2012-01-06","2012-01-09","2012-01-10","2012-01-11","2012-01-12","2012-01-13","2012-01-17","2012-01-18","2012-01-19","2012-01-20","2012-01-23","2012-01-24","2012-01-25","2012-01-26","2012-01-27","2012-01-30","2012-01-31","2012-02-01","2012-02-02" ...

# %% [markdown]
# ## Vectorized Backtesting

# %% [markdown]
# The **log returns** build the basis for the vectorized backtesting.

# %%
data['RETURNS'] = np.log(data['CLOSE'] / data['CLOSE'].shift(1))  # log returns in vectorized fashion

# %%
data['RETURNS'].head()
# Out:
# Date
# 2010-12-31        <NA>
# 2011-01-03      0.0215
# 2011-01-04    0.005205
# 2011-01-05    0.008147
# 2011-01-06   -0.000809
# Name: RETURNS, dtype: Float64

# %%
data.dropna(inplace=True)

# %%
data['RETURNS'].iplot(kind='histogram', subplots=True)
# Out:
# <div>                            <div id="736f3168-1a82-4ecf-b1df-0c3b6a55492e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("736f3168-1a82-4ecf-b1df-0c3b6a55492e")) {                    Plotly.newPlot(                        "736f3168-1a82-4ecf-b1df-0c3b6a55492e",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#4D5663","width":1.3}},"name":"RETURNS","opacity":0.8,"orientation":"v","x":[0.021499609032373416,0.005205350251826785,0.008146868249551076,-0.0008087101514541409,0.007135956234771195,0.018672023148938652,-0.0023827111310098367,0.008104291798807062,0.003651648746924235,0.008067348120917922,-0.022725282524918528,-0.005327537656327069,-0.018346952562863336,-0.018077532024185904,0.03231381621311454,0.011637459170924713,0.007150705405505138,-0.0018630110473900254,-0.020933769987395025,0.009534880208473836,0.016687754833065636,-0.0020599122392347255,-0.002559033617059787,0.008870394713652668,0.015407389754515836,0.009390802733541124,0.008298802814695284,-0.010158639347071839,0.0064943508314381,0.006508130173514028,0.002002559494394604,0.008934681789560833,-0.013390272563637586,-0.021838748463751757,-0.03468287321151167,0.011772958666667725,0.0007585704229543332,0.015281612502256221,0.014400636672269903,-0.011103000810856425,0.008012246503768604,0.020909035112493205,0.0012229697449571443,-0.012972671304038435,0.0011249860563237175,-0.009290833954849947,-0.016592193441894467,0.015229447297945528,0.004450436089105023,-0.023263184432577293,-0.045667060728468524,0.013932370102241503,-0.01193442792282778,0.02576377257906948,0.005584143827339434,-0.005908393266428652,0.016897034377587855,0.01886604605606913,-0.003133994986589171,0.0014827490597953132,-0.006661068955066384,-0.0003514371304392339,-0.01139151002659764,-0.00982873388139217,-0.006763935916075378,-0.002511339272106047,0.00011832219146505764,-0.00897293360236032,-0.012795657115850026,0.0048250998317568945,0.011158926915468829,-0.011098760253797788,-0.015033319431617861,0.013317149380587718,0.017948548902648076,0.013377240954006052,0.023910901872589208,0.006573801037816363,-0.007361117300052325,-0.000770800957414936,-0.009757574906585716,0.00970045489743116,-0.011056817744799111,0.005529330986515693,0.003926800408221531,-0.008099768547369096,-0.00025958668177651596,0.002707920878072709,0.005308096531900943,-0.006373105339731677,-0.001902566154761384,-0.01766969283907797,-0.021372140275872906,0.008484754534726418,0.011035451705086465,0.0019400358818507605,-0.01571619473624512,-0.002449151488565936,-0.006630786832419915,0.013722803804036267,-0.005299366357096508,0.007168276258973799,0.030415046585502207,-0.006692268320616806,0.0017119429523595121,-0.007721105384979908,-0.015848192240023616,-0.017908788089446577,0.0006021557356632968,-0.002259956064100024,-0.01700705741488235,0.002145594692849005,0.017723212148460902,-0.017264040180494294,-0.004877983625959644,-0.015184202984040943,-0.015545169702623223,0.031159837287598312,-0.008303670128518239,0.026368834768367624,-0.014842573037928852,0.01728501850560844,0.009650906616296787,-0.0036456039181029325,0.004867788202710674,0.02235964302075295,0.017815077982395733,0.006645869381666585,0.015346724129789461,0.007002302258027188,-0.01600123812659685,-0.0007064641763269951,0.011998401804598083,-0.0006985289265441533,0.019787829641772253,0.02404274354418897,0.008126335268016385,0.02631903141698829,0.0010075047029533429,0.015398913028343477,0.013134818792505984,0.01224591627361855,-0.02718760420344891,-0.001963259640553323,-0.003425799080994078,0.0159296078276264,-0.019958405024363086,0.009366910887960853,-0.039488726751225556,-0.009986900406475095,-0.056176457212622544,0.05721975412520022,-0.027980678598391696,0.027151480064836496,0.008765325405834246,0.01688625079457997,-0.007671299189435321,-0.00010513588823220146,-0.038558541521533186,-0.027754939128188476,0.0011509257800559598,0.04701978361016862,0.006882045887970803,-0.006560898317903489,0.026041350081935 ...

# %% [markdown]
# The next step is to derive the **returns of the strategy**, by mutliplying the positionings (shifted by one day to avoid a foresight bias) with the stock returns. I.e. a long position earns the stock return, a short position earns the negative value of the stock return.

# %%
data['STRATEGY'] = data['POSITIONS'].shift(1) * data['RETURNS']

# %%
data.dropna(inplace=True)

# %% [markdown]
# The final step is to add up the single resulting log returns over time and to apply the exponential functions to arrive at the **performance of the strategy compared to the benchmark of a passive investment in the stock**.

# %%
np.exp(data[['RETURNS', 'STRATEGY']].sum())
# Out:
# AAPL.O
# RETURNS     3.586375
# STRATEGY         NaN
# dtype: float64

# %% [markdown]
# The performance of the strategy can also be **compared over time** to the benchmark investment.

# %%
data[['RETURNS', 'STRATEGY']].iloc[1:].cumsum().applymap(np.exp).iplot()
# Out:
# <div>                            <div id="6abab4ce-c24c-41a2-a139-c14953c643a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("6abab4ce-c24c-41a2-a139-c14953c643a3")) {                    Plotly.newPlot(                        "6abab4ce-c24c-41a2-a139-c14953c643a3",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"RETURNS","text":"","x":["2011-01-03","2011-01-04","2011-01-05","2011-01-06","2011-01-07","2011-01
-12-21","2011-12-22","2011-12-23","2011-12-27","2011-12-28","2011-12-29","2011-12-30","2012-01-03","2012-01-04","2012-01-05","2012-01-06","2012-01-09","2012-01-10","2012-01-11","2012-01-12","2012-01-13","2012-01-17","2012-01-18","2012-01-19","2012-01-20","2012-01-23","2012-01-24","2012-01-25","2012-01-26","2012-01-27","2012-01-30","2012-01-31","2012-02-01","2012-02-02","2012-02-0 ...

# %% [markdown]
# ## Moving to Intraday Data

# %% [markdown]
# Let us repeat the analysis with intraday data and for a currency pair price.

# %%
ric = 'EUR='

# %%
data = ek.get_timeseries(ric,  # the RIC
                         fields='CLOSE',  # the required fields
                         start_date='2018-05-07 08:00:00',  # start time
                         end_date='2018-05-07 14:00:00',    # end time
                         interval='minute')

# %%
data.head()  # first five rows

# %%
data.info()  # DataFrame meta information

# %%
data.normalize().iplot(kind='lines')

# %% [markdown]
# The **SMAs** derived and visualized.

# %%
SMA1 = 10  # shorter SMA window
SMA2 = 30  # longer SMA window

# %%
data['SMA1'] = data['CLOSE'].rolling(SMA1).mean()
data['SMA2'] = data['CLOSE'].rolling(SMA2).mean()

# %%
data.dropna(inplace=True)

# %%
data.iplot()

# %% [markdown]
# The **positionings** derived and visualized.

# %%
data['POSITIONS'] = np.where(data['SMA1'] > data['SMA2'], 1, -1)

# %%
data.iplot(secondary_y='POSITIONS')

# %% [markdown]
# The **log returns** calculated.

# %%
data['RETURNS'] = np.log(data['CLOSE'] / data['CLOSE'].shift(1))  # log returns in vectorized fashion

# %%
data.dropna(inplace=True)

# %% [markdown]
# Finally, the **strategy returns** and the **performance** compared to the benchmark passive investment.

# %%
data['STRATEGY'] = data['POSITIONS'].shift(1) * data['RETURNS']

# %%
data.dropna(inplace=True)

# %%
np.exp(data[['RETURNS', 'STRATEGY']].sum())

# %%
data[['RETURNS', 'STRATEGY']].cumsum().apply(np.exp).iplot()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# Based on this tutorial, we can conclude that
#
# * it is easy to retrieve **historical end-of-day as well as intraday price data** via the Eikon Data API,
# * `Plotly` and `Cufflinks` make **financial data visualization** convenient and
# * `pandas` is a powerful data analysis tool to formulate and backtest **trading strategies** algorithmically and concisely based on **vectorized Python code**.

# %% [markdown]
# ## Eikon Data API Developer Resources

# %% [markdown]
# * [Overview](https://developers.thomsonreuters.com/eikon-data-apis)
# * [Quick Start ](https://developers.thomsonreuters.com/eikon-data-apis/quick-start)
# * [Documentation](https://developers.thomsonreuters.com/eikon-data-apis/docs)
# * [Downloads](https://developers.thomsonreuters.com/eikon-data-apis/downloads)
# * [Tutorials](https://developers.thomsonreuters.com/eikon-data-apis/learning)
# * [Q&A Forums](https://developers.thomsonreuters.com/eikon-data-apis/qa)
#
# Data Item Browser Application: Type `DIB` into Eikon Search Bar.

# %% [markdown]
# <img src="http://eikon.tpq.io/refinitiv_logo.png" width="28%" align="left" style="vertical-align: top; padding-top: 23px;">
# <img src="http://hilpisch.com/tpq_logo_long.png" width="36%" align="right" style="vertical-align: top;">
