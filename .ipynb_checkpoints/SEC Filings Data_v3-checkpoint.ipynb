# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import json
# from pandas import json_normalize

# %%
json_directory = '0_readonly/companyfacts/'

# %%
def process_json(data):
    processed_rows = []
    # Extract US-GAAP section if present
    if 'facts' in data and 'us-gaap' in data['facts']:
        us_gaap_data = data['facts']['us-gaap']
        for fact_key, fact_value in us_gaap_data.items():
            label = fact_value['label']
            description = fact_value['description']
            for unit_key, unit_value in fact_value['units'].items():
                for entry in unit_value:
                    row = {
                        'CIK': data.get('cik'),
                        'EntityName': data.get('entityName'),
                        'Section': 'US-GAAP',
                        'FactKey': fact_key,
                        'Label': label,
                        'Description': description,
                        'UnitKey': unit_key,
                        **entry
                    }
                    processed_rows.append(row)

    # Extract DEI section if present
    if 'facts' in data and 'dei' in data['facts']:
        dei_data = data['facts']['dei']
        for fact_key, fact_value in dei_data.items():
            label = fact_value['label']
            description = fact_value['description']
            for unit_key, unit_value in fact_value['units'].items():
                for entry in unit_value:
                    row = {
                        'CIK': data.get('cik'),
                        'EntityName': data.get('entityName'),
                        'Section': 'DEI',
                        'FactKey': fact_key,
                        'Label': label,
                        'Description': description,
                        'UnitKey': unit_key,
                        **entry
                    }
                    processed_rows.append(row)
                    
    # Extract INVEST section if present
    if 'facts' in data and 'invest' in data['facts']:
        invest_data = data['facts']['invest']
        for fact_key, fact_value in invest_data.items():            
            label = fact_value['label']
            description = fact_value['description']
            for unit_key, unit_value in fact_value['units'].items():
                for entry in unit_value:
                    row = {
                        'CIK': data.get('cik'),
                        'EntityName': data.get('entityName'),
                        'Section': 'Invest',
                        'FactKey': fact_key,
                        'Label': label,
                        'Description': description,
                        'UnitKey': unit_key,
                        **entry
                    }
                    processed_rows.append(row)                   

    # Extract SRT section if present
    if 'facts' in data and 'srt' in data['facts']:
        srt_data = data['facts']['srt']
        for fact_key, fact_value in srt_data.items():
            label = fact_value['label']
            description = fact_value['description']
            for unit_key, unit_value in fact_value['units'].items():
                for entry in unit_value:
                    row = {
                        'CIK': data.get('cik'),
                        'EntityName': data.get('entityName'),
                        'Section': 'SRT',
                        'FactKey': fact_key,
                        'Label': label,
                        'Description': description,
                        'UnitKey': unit_key,
                        **entry
                    }
                    processed_rows.append(row)           
            
            
    if processed_rows:
        df = pd.DataFrame(processed_rows)
        return df
    else:
        return None

# %%
dataframes = []

# %%
# Get a list of all JSON files in the directory
json_files = [filename for filename in os.listdir(json_directory) if filename.endswith('.json')]

# Sort the files by file size
file_list = sorted(json_files, key=lambda filename: os.path.getsize(os.path.join(json_directory, filename)), reverse=True)

'''
for idx, filename in enumerate(sorted_files, start=1):
    json_path = os.path.join(json_directory, filename)
    # Process the file as needed
    print(f"File {idx}/{len(sorted_files)} - Name: {filename}, Size: {os.path.getsize(json_path)} bytes")
'''
# Out:
# '\nfor idx, filename in enumerate(sorted_files, start=1):\n    json_path = os.path.join(json_directory, filename)\n    # Process the file as needed\n    print(f"File {idx}/{len(sorted_files)} - Name: {filename}, Size: {os.path.getsize(json_path)} bytes")\n'

# %%
#json_directory = "path_to_your_directory"
#file_list = sorted([filename for filename in os.listdir(json_directory) if filename.endswith('.json')])
#start_idx = int(len(file_list) // 10)
#end_idx = int((len(file_list) // 10) * 2)

start_idx = 1
end_idx = 100


for idx in range(start_idx - 1, min(end_idx, len(file_list))):
    filename = file_list[idx]
    json_path = os.path.join(json_directory, filename)
    with open(json_path, 'r') as json_file:
        try:
            data = json.load(json_file)
            entity_name = data.get('entityName', 'Unknown Entity')
            print(f"Processing file {idx+1}/{len(file_list)}: {entity_name}")
            processed_data = process_json(data)  # Define the processing function
            if processed_data is not None:
                dataframes.append(processed_data)
        except json.JSONDecodeError:
            print(f"Error decoding JSON in file: {json_path}")
# Out:
# Processing file 1/17265: MetLife, Inc.
# Processing file 2/17265: WELLS FARGO & COMPANY/MN
# Processing file 3/17265: THE BANK OF NEW YORK MELLON CORPORATION
# Processing file 4/17265: CitigroupÂ Inc
# Processing file 5/17265: POPULAR, INC.
# Processing file 6/17265: JPMorgan Chase & Co
# Processing file 7/17265: FIFTH THIRD BANCORP
# Processing file 8/17265: WEBSTER FINANCIAL CORPORATION
# Processing file 9/17265: WINTRUST FINANCIAL CORP
# Processing file 10/17265: Ally Financial Inc.
# Processing file 11/17265: Bank of America Corporation
# Processing file 12/17265: MORGAN STANLEY
# Processing file 13/17265: Old National Bancorp
# Processing file 14/17265: American International Group, Inc.
# Processing file 15/17265: CAPITALÂ ONEÂ FINANCIALÂ CORP
# Processing file 16/17265: Regions Financial Corporation
# Processing file 17/17265: SANTANDER HOLDINGS USA, INC.
# Processing file 18/17265: GENWORTH FINANCIAL, INC.
# Processing file 19/17265: US BANCORP \DE\
# Processing file 20/17265: Prudential Financial, Inc.
# Processing file 21/17265: FIRST HORIZON CORP
# Processing file 22/17265: KeyCorp
# Processing file 23/17265: ZIONS BANCORPORATION, NATIONAL ASSOCIATION
# Processing file 24/17265: Huntington Bancshares Incorporated
# Processing file 25/17265: JEFFERIES FINANCIAL GROUP INC.
# Processing file 26/17265: Cullen/Frost Bankers, Inc.
# Processing file 27/17265: GENERAL ELECTRIC COMPANY
# Processing file 28/17265: THE AES CORPORATION
# Processing file 29/17265: PARK NATIONAL CORPORATION
# Processing file 30/17265: M&T BANK CORPORATION
# Processing file 31/17265: PNC Financial Services Group, Inc.
# Processing file 32/17265: Peopleâ€™s United Financial, Inc.
# Processing file 33/17265: Associated Banc-Corp
# Processing file 34/17265: Valley National Bancorp
# Processing file 35/17265: STATE STREET CORPORATION
# Processing file 36/17265: THE HARTFORD FINANCIAL SERVICES GROUP, INC.
# Processing file 37/17265: CISCO SYSTEMS, INC.
# Processing file 38/17265: BOK FINANCIAL CORP
# Processing file 39/17265: CATERPILLAR INC
# Processing file 40/17265: FIRST FINANCIAL BANCORP /OH/
# Processing file 41/17265: UNITED BANKSHARES INC/WV
# Processing file 42/17265: FNB CORP/PA/
# Processing file 43/17265: BANC OF CALIFORNIA, INC.
# Processing file 44/17265: Elevance Health, Inc.
# Processing file 45/17265: Premier Financial Corp.
# Processing file 46/17265: RENASANT CORP
# Processing file 47/17265: ALLSTATE CORP
# Processing file 48/17265: Independent Bank Corp.
# Processing file 49/17265: SOUTHSIDE BANCSHARES, INC.
# Processing file 50/17265: NEWMONT CORPORATION
# Processing file 51/17265: First Savings Financial Group,Â Inc.
# Processing file 52/17265: TRUIST FINANCIAL CORPORATION
# Processing file 53/17265: Pitney Bowes Inc.
# Processing file 54/17265: BRISTOL-MYERS SQUIBB COMPANY
# Processing file 55/17265: STIFEL FINANCIAL CORP
# Processing file 56/17265: SYNOVUS FINANCIAL CORP
# Processing file 57/17265: HEARTLAND FINANCIAL USA, INC.
# Processing file 58/17265: INTERNATIONAL BUSINESS MACHINES CORPORATION
# Processing file 59/17265: Umpqua Holdings Corporation
# Processing file 60/17265: WESTERN ALLIANCE BANCORPORATION
# Processing file 61/17265: FIRST BANCORP
# Processing file 62/17265: BANNER CORPORATION
# Processing file 63/17265: FIRST MERCHANTS CORP
# Processing file 64/17265: NORTHERN TRUST CORPORATION
# Processing file 65/17265: FIRST COMMONWEALTH FINANCIAL CORP /PA/
# Processing file 66/17265: EXELON CORPORATION
# Processing file 67/17265: PPG INDUSTRIES INC
# Processing file 68/17265: UNITED COMMUNITY BANKS, INC.
# Processing file 69/17265: FIRST BANCORP, INC
# Processing file 70/17265: TriCo Bancshares
# Processing file 71/17265: WELLTOWER INC.
# Processing file 72/17265: Diebold Nixdorf, Incorporated
# Processing file 73/17265: FMC CORPORATION
# Processing file 74/17265: WSFS FINANCIAL CORPORATION
# Processing file 75/17265: CNX Resources Corporation
# Processing file 76/17265: Voya Financial, Inc.
# Processing file 77/17265: FIRST INTERSTATE BANCSYSTEM, INC.
# Processing file 78/17265: Customers Bancorp, Inc.
# Processing file 79/17265: CELANESE CORPORATION
# Processing file 80/17265: DOMINION ENERGY, INC.
# Processing file 81/17265: Olin Corporation
# Processing file 82/17265: DUKE ENERGY CORPORATION
# Processing file 83/17265: SUNTRUST BANKS INC
# Processing file 84/17265: MIDWESTONE FINANCIAL GROUP, INC.
# Processing file 85/17265: QCR HOLDINGS,Â INC.
# Processing file 86/17265: BROOKLINE BANCORP,Â INC
# Processing file 87/17265: GRAHAM HOLDINGS CO
# Processing file 88/17265: RAYMOND JAMES FINANCIAL, INC.
# Processing file 89/17265: CAMDEN NATIONAL CORP
# Processing file 90/17265: MOTOROLA SOLUTIONS,Â INC.
# Processing file 91/17265: UNIVEST FINANCIAL CORPORATION
# Processing file 92/17265: BANK OF HAWAII CORPORATION
# Processing file 93/17265: Metropolitan Life Insurance Co
# Processing file 94/17265: ATLANTIC UNION BANKSHARES CORPORATION
# Processing file 95/17265: PROVIDENT FINANCIAL SERVICES, INC.
# Processing file 96/17265: 3M COMPANY
# Processing file 97/17265: ConnectOne Bancorp, Inc.
# Processing file 98/17265: FIRST MID BANCSHARES, INC.
# Processing file 99/17265: AMERICAN ELECTRIC POWER CO INC.
# Processing file 100/17265: ITRON, INC.

# %%
final_dataframe = pd.concat(dataframes, ignore_index=True)

# %%
final_dataframe.shape
# Out:
# (3326991, 16)

# %%
final_dataframe.head()
# Out:
#        CIK     EntityName  Section  \
# 0  1099219  MetLife, Inc.  US-GAAP
# 1  1099219  MetLife, Inc.  US-GAAP
# 2  1099219  MetLife, Inc.  US-GAAP
# 3  1099219  MetLife, Inc.  US-GAAP
# 4  1099219  MetLife, Inc.  US-GAAP
#
#                                              FactKey  \
# 0  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 1  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 2  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 3  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 4  AccretionAmortizationOfDiscountsAndPremiumsInv...
#
#                                                Label  \
# 0  Accretion (Amortization) of Discounts and Prem...
# 1  Accretion (Amortization) of Discounts and Prem...
# 2  Accretion (Amortization) of Discounts and Prem...
# 3  Accretion (Amortization) of Discounts and Prem...
# 4  Accretion (Amortization) of Discounts and Prem...
#
#                                          Description UnitKey       start  \
# 0  The sum of the periodic adjustments of the dif...     USD  2007-01-01
# 1  The sum of the periodic adjustments of the dif...     USD  2008-01-01
# 2  The sum of the periodic adjustments of the dif...     USD  2008-01-01
# 3  The sum of the periodic adjustments of the dif...     USD  2008-01-01
# 4  The sum of the periodic adjustments of the dif...     USD  2009-01-01
#
#           end          val                  accn      fy  fp  form  \
# 0  2007-12-31 -955000000.0  0000950123-10-018284  2009.0  FY  10-K
# 1  2008-06-30 -526000000.0  0000950123-09-029190  2009.0  Q2  10-Q
# 2  2008-12-31 -939000000.0  0000950123-10-018284  2009.0  FY  10-K
# 3  2008-12-31  939000000.0  0000950123-11-018077  2010.0  FY  10-K
# 4  2009-06-30 -287000000.0  0000950123-09-029190  2009.0  Q2  10-Q
#
#         filed   frame
# 0  2010-02-26  CY2007
# 1  2009-08-04     NaN
# 2  2010-02-26     NaN
# 3  2011-02-25  CY2008
# 4  2009-08-04     NaN

# %%
final_dataframe.FactKey.value_counts()[0:10]
# Out:
# EarningsPerShareDiluted                            23212
# EarningsPerShareBasic                              23031
# NetIncomeLoss                                      22150
# IncomeTaxExpenseBenefit                            20931
# InterestExpense                                    18757
# WeightedAverageNumberOfSharesOutstandingBasic      18444
# WeightedAverageNumberOfDilutedSharesOutstanding    18243
# StockholdersEquity                                 15724
# ComprehensiveIncomeNetOfTax                        15327
# AccumulatedOtherComprehensiveIncomeLossNetOfTax    15048
# Name: FactKey, dtype: int64

# %%
final_dataframe.FactKey.value_counts().reset_index().to_csv('x.csv', index=False)

# %%
final_dataframe[final_dataframe.form=='10-Q'].FactKey.value_counts().reset_index().to_csv('x2.csv', index=False)

# %%
final_dataframe[final_dataframe.FactKey=='NetIncomeLoss'].head()
# Out:
#            CIK     EntityName  Section        FactKey  \
# 33084  1099219  MetLife, Inc.  US-GAAP  NetIncomeLoss
# 33085  1099219  MetLife, Inc.  US-GAAP  NetIncomeLoss
# 33086  1099219  MetLife, Inc.  US-GAAP  NetIncomeLoss
# 33087  1099219  MetLife, Inc.  US-GAAP  NetIncomeLoss
# 33088  1099219  MetLife, Inc.  US-GAAP  NetIncomeLoss
#
#                                           Label  \
# 33084  Net Income (Loss) Attributable to Parent
# 33085  Net Income (Loss) Attributable to Parent
# 33086  Net Income (Loss) Attributable to Parent
# 33087  Net Income (Loss) Attributable to Parent
# 33088  Net Income (Loss) Attributable to Parent
#
#                                              Description UnitKey       start  \
# 33084  The portion of profit or loss for the period, ...     USD  2007-01-01
# 33085  The portion of profit or loss for the period, ...     USD  2008-01-01
# 33086  The portion of profit or loss for the period, ...     USD  2008-04-01
# 33087  The portion of profit or loss for the period, ...     USD  2008-01-01
# 33088  The portion of profit or loss for the period, ...     USD  2008-07-01
#
#               end           val                  accn      fy  fp  form  \
# 33084  2007-12-31  4.317000e+09  0000950123-10-018284  2009.0  FY  10-K
# 33085  2008-06-30  1.594000e+09  0000950123-09-029190  2009.0  Q2  10-Q
# 33086  2008-06-30  9.460000e+08  0000950123-09-029190  2009.0  Q2  10-Q
# 33087  2008-09-30  2.224000e+09  0000950123-09-057114  2009.0  Q3  10-Q
# 33088  2008-09-30  6.300000e+08  0000950123-09-057114  2009.0  Q3  10-Q
#
#             filed     frame
# 33084  2010-02-26    CY2007
# 33085  2009-08-04       NaN
# 33086  2009-08-04  CY2008Q2
# 33087  2009-11-04       NaN
# 33088  2009-11-04  CY2008Q3

# %%
# Calculate the value counts for the column
value_counts = final_dataframe['FactKey'].value_counts()

# Choose the number of highest value counts to consider
num_highest = 5  # Change this to the desired number

# Get the top 'num_highest' values based on value counts
top_values = value_counts.head(num_highest).index

# Filter the DataFrame based on the top values
filtered_df = final_dataframe[final_dataframe['FactKey'].isin(top_values)]

# %%
filtered_df.form.value_counts()
# Out:
# 10-Q      64220
# 10-K      39159
# 8-K        2846
# 10-Q/A     1187
# 10-K/A      626
# 10-KT        43
# Name: form, dtype: int64

# %%
filtered_df.shape
# Out:
# (108081, 16)

# %%
filtered_df.CIK.unique()
# Out:
# array([1099219,   72971, 1390777,  831001,  763901,   19617,   35527,
#         801337, 1015328,   40729,   70858,  895421,  707179,    5272,
#         927628, 1281761,  811830, 1276520,   36104, 1137774,   36966,
#          91576,  109380,   49196,   96223,   39263,   40545,  874761,
#         805676,   36270,  713676, 1378946,    7789,  714310,   93751,
#         874766,  858877,  875357,   18230,  708955,  729986,   37808,
#        1169770, 1156039,  946647,  715072,  899051,  776901,  705432,
#        1164727, 1435508,   92230,   78814,   14272,  720672,   18349,
#         920112,   51143, 1077771, 1212545, 1057706,  946673,  712534,
#          73124,  712537, 1109357,   79879,  857855,  765207,  356171,
#         766704,   28823,   37785,  828944, 1070412, 1535929,  860413,
#        1488813, 1306830,  715957,   74303, 1326160,  750556, 1412665,
#         906465, 1049782,  104889,  720005,  750686,   68505,  102212,
#          46195,  937834,  883948, 1178970,   66740,  712771,  700565,
#           4904,  780571], dtype=int64)

# %%
filtered_df.dtypes
# Out:
# CIK              int64
# EntityName      object
# Section         object
# FactKey         object
# Label           object
# Description     object
# UnitKey         object
# start           object
# end             object
# val            float64
# accn            object
# fy             float64
# fp              object
# form            object
# filed           object
# frame           object
# dtype: object

# %%
filtered_df.fy.unique()
# Out:
# array([2009., 2010., 2011., 2012., 2013., 2014., 2015.,    0., 2016.,
#        2017., 2018., 2019., 2020., 2021., 2022., 2023.,   nan, 2008.])

# %%
# Drop rows with missing values
df_cleaned = final_dataframe.dropna()

# %%
df_cleaned.shape
# Out:
# (668949, 16)

# %%
import requests

# %%
# create request header
headers = {'User-Agent': "drewnsingh@gmail.com"}

# get all companies data
companyTickers = requests.get(
    "https://www.sec.gov/files/company_tickers.json",
    headers=headers
    )

# %%
# dictionary to dataframe
companyData = pd.DataFrame.from_dict(companyTickers.json(),
                                     orient='index')

# %%
companyData.shape
# Out:
# (8957, 3)

# %%
companyData.rename(columns={'cik_str': 'CIK'}, inplace=True)

# %%
companyData_cleaned = companyData[~companyData['ticker'].str.contains('-')]

# %%
df_cleaned2 = pd.merge(df_cleaned, companyData_cleaned, on="CIK", how="left")

# %%
df_cleaned2.head()
# Out:
#        CIK     EntityName  Section  \
# 0  1099219  MetLife, Inc.  US-GAAP
# 1  1099219  MetLife, Inc.  US-GAAP
# 2  1099219  MetLife, Inc.  US-GAAP
# 3  1099219  MetLife, Inc.  US-GAAP
# 4  1099219  MetLife, Inc.  US-GAAP
#
#                                              FactKey  \
# 0  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 1  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 2  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 3  AccretionAmortizationOfDiscountsAndPremiumsInv...
# 4  AccretionAmortizationOfDiscountsAndPremiumsInv...
#
#                                                Label  \
# 0  Accretion (Amortization) of Discounts and Prem...
# 1  Accretion (Amortization) of Discounts and Prem...
# 2  Accretion (Amortization) of Discounts and Prem...
# 3  Accretion (Amortization) of Discounts and Prem...
# 4  Accretion (Amortization) of Discounts and Prem...
#
#                                          Description UnitKey       start  \
# 0  The sum of the periodic adjustments of the dif...     USD  2007-01-01
# 1  The sum of the periodic adjustments of the dif...     USD  2008-01-01
# 2  The sum of the periodic adjustments of the dif...     USD  2009-01-01
# 3  The sum of the periodic adjustments of the dif...     USD  2010-01-01
# 4  The sum of the periodic adjustments of the dif...     USD  2011-01-01
#
#           end           val                  accn      fy  fp  form  \
# 0  2007-12-31 -9.550000e+08  0000950123-10-018284  2009.0  FY  10-K
# 1  2008-12-31  9.390000e+08  0000950123-11-018077  2010.0  FY  10-K
# 2  2009-12-31  9.670000e+08  0001193125-12-474227  2011.0  FY   8-K
# 3  2010-12-31  1.078000e+09  0001193125-13-077792  2012.0  FY  10-K
# 4  2011-12-31  4.770000e+08  0000937834-14-000011  2013.0  FY  10-K
#
#         filed   frame ticker        title
# 0  2010-02-26  CY2007    MET  METLIFE INC
# 1  2011-02-25  CY2008    MET  METLIFE INC
# 2  2012-11-16  CY2009    MET  METLIFE INC
# 3  2013-02-27  CY2010    MET  METLIFE INC
# 4  2014-02-27  CY2011    MET  METLIFE INC

# %%
list(df_cleaned2.ticker.unique())
# Out:
# ['MET',
#  'WFC',
#  'BK',
#  'C',
#  'BPOP',
#  'BPOPM',
#  'JPM',
#  'AMJ',
#  'FITB',
#  'FITBI',
#  'FITBP',
#  'FITBO',
#  'WBS',
#  'WTFC',
#  'WTFCM',
#  'WTFCP',
#  'ALLY',
#  'BAC',
#  'MS',
#  'ONB',
#  'ONBPP',
#  'AIG',
#  'COF',
#  'RF',
#  nan,
#  'GNW',
#  'USB',
#  'PRU',
#  'PRH',
#  'PRS',
#  'FHN',
#  'KEY',
#  'ZION',
#  'ZIONP',
#  'ZIONL',
#  'ZIONO',
#  'HBAN',
#  'HBANP',
#  'HBANM',
#  'JEF',
#  'CFR',
#  'GE',
#  'AES',
#  'AESC',
#  'PRK',
#  'MTB',
#  'PNC',
#  'ASB',
#  'ASBA',
#  'VLY',
#  'VLYPP',
#  'STT',
#  'HIG',
#  'CSCO',
#  'BOKF',
#  'CAT',
#  'FFBC',
#  'UBSI',
#  'FNB',
#  'BANC',
#  'ELV',
#  'PFC',
#  'RNST',
#  'ALL',
#  'INDB',
#  'SBSI',
#  'NEM',
#  'FSFG',
#  'TFC',
#  'PBI',
#  'BMY',
#  'SF',
#  'SFB',
#  'SNV',
#  'HTLF',
#  'HTLFP',
#  'IBM',
#  'WAL',
#  'FBP',
#  'BANR',
#  'FRME',
#  'FRMEP',
#  'NTRS',
#  'NTRSO',
#  'FCF',
#  'EXC',
#  'PPG',
#  'UCBI',
#  'FNLC',
#  'TCBK',
#  'WELL',
#  'DBD',
#  'DBDQQ',
#  'FMC',
#  'WSFS',
#  'CNX',
#  'VOYA',
#  'FIBK',
#  'CUBI',
#  'CE',
#  'D',
#  'OLN',
#  'DUK',
#  'DUKB',
#  'MOFG',
#  'QCRH',
#  'BRKL',
#  'GHC',
#  'RJF',
#  'CAC',
#  'MSI',
#  'UVSP',
#  'BOH',
#  'AUB',
#  'PFS',
#  'MMM',
#  'CNOB',
#  'CNOBP',
#  'FMBH',
#  'AEP',
#  'AEPPZ',
#  'ITRI']

# %%
sorted_unique_tickers = sorted(df_cleaned2['ticker'].astype(str).unique())
print(sorted_unique_tickers)
# Out:
# ['AEP', 'AEPPZ', 'AES', 'AESC', 'AIG', 'ALL', 'ALLY', 'AMJ', 'ASB', 'ASBA', 'AUB', 'BAC', 'BANC', 'BANR', 'BK', 'BMY', 'BOH', 'BOKF', 'BPOP', 'BPOPM', 'BRKL', 'C', 'CAC', 'CAT', 'CE', 'CFR', 'CNOB', 'CNOBP', 'CNX', 'COF', 'CSCO', 'CUBI', 'D', 'DBD', 'DBDQQ', 'DUK', 'DUKB', 'ELV', 'EXC', 'FBP', 'FCF', 'FFBC', 'FHN', 'FIBK', 'FITB', 'FITBI', 'FITBO', 'FITBP', 'FMBH', 'FMC', 'FNB', 'FNLC', 'FRME', 'FRMEP', 'FSFG', 'GE', 'GHC', 'GNW', 'HBAN', 'HBANM', 'HBANP', 'HIG', 'HTLF', 'HTLFP', 'IBM', 'INDB', 'ITRI', 'JEF', 'JPM', 'KEY', 'MET', 'MMM', 'MOFG', 'MS', 'MSI', 'MTB', 'NEM', 'NTRS', 'NTRSO', 'OLN', 'ONB', 'ONBPP', 'PBI', 'PFC', 'PFS', 'PNC', 'PPG', 'PRH', 'PRK', 'PRS', 'PRU', 'QCRH', 'RF', 'RJF', 'RNST', 'SBSI', 'SF', 'SFB', 'SNV', 'STT', 'TCBK', 'TFC', 'UBSI', 'UCBI', 'USB', 'UVSP', 'VLY', 'VLYPP', 'VOYA', 'WAL', 'WBS', 'WELL', 'WFC', 'WSFS', 'WTFC', 'WTFCM', 'WTFCP', 'ZION', 'ZIONL', 'ZIONO', 'ZIONP', 'nan']

# %%
len(df_cleaned2.CIK.unique())
# Out:
# 100

# %%
df_cleaned2.shape
# Out:
# (851056, 18)

# %%
from sec_api import MappingApi

mappingApi = MappingApi(api_key='a706e316b8b9c2e16f45c98fec053d2f6437c32462feb8e12caac444a6dc5dc9')

# %%
by_cik = mappingApi.resolve('cik', '72971')

print('CIK:\t',     '72971')
print('Ticker:\t',  by_cik[0]['ticker'])
print('CUSIP:\t',   by_cik[0]['cusip'])
print('')
print('CIK "1065280" resolved to its company details')
print('---------------------------------------------')
by_cik
# Out:
# CIK:	 72971
# Ticker:	 WFC
# CUSIP:	 949746101 949740104 669380107 929798106 668231103
#
# CIK "1065280" resolved to its company details
# ---------------------------------------------
# [{'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC',
#   'cik': '72971',
#   'cusip': '949746101 949740104 669380107 929798106 668231103',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Common Stock Primary Class',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'bdf7578180a28caab21dff665cedbefd'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PA',
#   'cik': '72971',
#   'cusip': '94988U128',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '7f7d829eb3726c9f59c522d02055be6a'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PC',
#   'cik': '72971',
#   'cusip': '95002Y202',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'cfd2fe2f589f291f9bf76c8aa07e8a00'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PD',
#   'cik': '72971',
#   'cusip': '95002Y400',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'a5fd56986e07ada7fd4e7ee516f657f9'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PJ',
#   'cik': '72971',
#   'cusip': '949746879',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'b32cdfeeb772691ce73feb1ad845991f'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PL',
#   'cik': '72971',
#   'cusip': '949746804',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '6e804571fda48612f255955fc9218d5e'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PN',
#   'cik': '72971',
#   'cusip': '949746747',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'c9b82fea512622d3cb16c6c51576b927'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PO',
#   'cik': '72971',
#   'cusip': '949746721',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '7a70bdcdaa2d167207611dd61e3f196b'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PP',
#   'cik': '72971',
#   'cusip': '949746655',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '3ed42e122ba9fac7736af3b090cb2b1f'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PQ',
#   'cik': '72971',
#   'cusip': '949746556',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'b30ce121607ad2b19a8ac304b674d799'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PR',
#   'cik': '72971',
#   'cusip': '949746465',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '2647ebade72b420de3e483cbb3944d67'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PT',
#   'cik': '72971',
#   'cusip': '949746366',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '41d64148ee285db6a52755ccea60c151'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PV',
#   'cik': '72971',
#   'cusip': '94988U730',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'be1b4402a63afbb732ab7c92a41fc350'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PW',
#   'cik': '72971',
#   'cusip': '94988U714',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'faa6587512a9b316d6e28f3fdd701a82'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PX',
#   'cik': '72971',
#   'cusip': '94988U672',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '914fe5a8536a0126aa6748ef4af03789'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PY',
#   'cik': '72971',
#   'cusip': '94988U656',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'd74b860a86a351a06c5317f6e97a7095'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC-PZ',
#   'cik': '72971',
#   'cusip': '94988U151',
#   'exchange': 'NYSE',
#   'isDelisted': False,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'd05a48143231160dc799c70cd6da0ebc'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFC.WS',
#   'cik': '72971',
#   'cusip': '949746119',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Common Stock Warrant',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'c65077fb9c641bd7d00f144cff51c120'},
#  {'name': 'WELLS FARGO & COMPANY',
#   'ticker': 'WFE-PA',
#   'cik': '72971',
#   'cusip': '94988N207',
#   'exchange': 'NYSE',
#   'isDelisted': True,
#   'category': 'Domestic Preferred Stock',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': 'bfb7e6001e9e550b44cac145add07639'},
#  {'name': 'WELLS FARGO COMPANY',
#   'ticker': 'N/A',
#   'cik': '72971',
#   'cusip': '',
#   'exchange': '',
#   'isDelisted': False,
#   'category': '',
#   'sector': 'Financial Services',
#   'industry': 'Banks - Diversified',
#   'sic': '6021',
#   'sicSector': 'Finance Insurance And Real Estate',
#   'sicIndustry': 'National Commercial Banks',
#   'famaSector': '',
#   'famaIndustry': 'Banking',
#   'currency': 'USD',
#   'location': 'California; U.S.A',
#   'id': '60b6d68190e02e4c62470e75c903da30'}]

# %%
df = pd.json_normalize(by_cik)

# %%
df.head()
# Out:
#                     name  ticker    cik  \
# 0  WELLS FARGO & COMPANY     WFC  72971
# 1  WELLS FARGO & COMPANY  WFC-PA  72971
# 2  WELLS FARGO & COMPANY  WFC-PC  72971
# 3  WELLS FARGO & COMPANY  WFC-PD  72971
# 4  WELLS FARGO & COMPANY  WFC-PJ  72971
#
#                                                cusip exchange  isDelisted  \
# 0  949746101 949740104 669380107 929798106 668231103     NYSE       False
# 1                                          94988U128     NYSE       False
# 2                                          95002Y202     NYSE       False
# 3                                          95002Y400     NYSE       False
# 4                                          949746879     NYSE        True
#
#                               category              sector  \
# 0  Domestic Common Stock Primary Class  Financial Services
# 1             Domestic Preferred Stock  Financial Services
# 2             Domestic Preferred Stock  Financial Services
# 3             Domestic Preferred Stock  Financial Services
# 4             Domestic Preferred Stock  Financial Services
#
#               industry   sic                          sicSector  \
# 0  Banks - Diversified  6021  Finance Insurance And Real Estate
# 1  Banks - Diversified  6021  Finance Insurance And Real Estate
# 2  Banks - Diversified  6021  Finance Insurance And Real Estate
# 3  Banks - Diversified  6021  Finance Insurance And Real Estate
# 4  Banks - Diversified  6021  Finance Insurance And Real Estate
#
#                  sicIndustry famaSector famaIndustry currency  \
# 0  National Commercial Banks                 Banking      USD
# 1  National Commercial Banks                 Banking      USD
# 2  National Commercial Banks                 Banking      USD
# 3  National Commercial Banks                 Banking      USD
# 4  National Commercial Banks                 Banking      USD
#
#             location                                id
# 0  California; U.S.A  bdf7578180a28caab21dff665cedbefd
# 1  California; U.S.A  7f7d829eb3726c9f59c522d02055be6a
# 2  California; U.S.A  cfd2fe2f589f291f9bf76c8aa07e8a00
# 3  California; U.S.A  a5fd56986e07ada7fd4e7ee516f657f9
# 4  California; U.S.A  b32cdfeeb772691ce73feb1ad845991f

# %%
df.category.unique()
# Out:
# array(['Domestic Common Stock Primary Class', 'Domestic Preferred Stock',
#        'Domestic Common Stock Warrant', ''], dtype=object)

# %%
df_cleaned.CIK.unique()
# Out:
# array([1099219,   72971, 1390777,  831001,  763901,   19617,   35527,
#         801337, 1015328,   40729,   70858,  895421,  707179,    5272,
#         927628, 1281761,  811830, 1276520,   36104, 1137774,   36966,
#          91576,  109380,   49196,   96223,   39263,   40545,  874761,
#         805676,   36270,  713676, 1378946,    7789,  714310,   93751,
#         874766,  858877,  875357,   18230,  708955,  729986,   37808,
#        1169770, 1156039,  946647,  715072,  899051,  776901,  705432,
#        1164727, 1435508,   92230,   78814,   14272,  720672,   18349,
#         920112,   51143, 1077771, 1212545, 1057706,  946673,  712534,
#          73124,  712537, 1109357,   79879,  857855,  765207,  356171,
#         766704,   28823,   37785,  828944, 1070412, 1535929,  860413,
#        1488813, 1306830,  715957,   74303, 1326160,  750556, 1412665,
#         906465, 1049782,  104889,  720005,  750686,   68505,  102212,
#          46195,  937834,  883948, 1178970,   66740,  712771,  700565,
#           4904,  780571], dtype=int64)

# %%
# Your existing code for resolving a single CIK
def resolve_cik(cik):
    return mappingApi.resolve('cik', str(cik))

# List of CIKs
cik_list = df_cleaned.CIK.unique()

# List to hold individual dataframes
dfs = []

for cik in cik_list:
    by_cik = resolve_cik(cik)
    df = pd.json_normalize(by_cik)
    dfs.append(df)

# Concatenate all dataframes into a single dataframe
concatenated_df = pd.concat(dfs, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13416\1699293990.py in <module>
#      10
#      11 for cik in cik_list:
# ---> 12     by_cik = resolve_cik(cik)
#      13     df = pd.json_normalize(by_cik)
#      14     dfs.append(df)
#
# ~\AppData\Local\Temp\ipykernel_13416\1699293990.py in resolve_cik(cik)
#       1 # Your existing code for resolving a single CIK
#       2 def resolve_cik(cik):
# ----> 3     return mappingApi.resolve('cik', cik)
#       4
#       5 # List of CIKs
#
# ~\AppData\Roaming\Python\Python39\site-packages\sec_api\index.py in resolve(self, parameter, value)
#     221         response = {}
#     222         _url = (
# --> 223             self.api_endpoint
#     224             + "/"
#     225             + parameter.lower()
#
# TypeError: can only concatenate str (not "numpy.int64") to str
